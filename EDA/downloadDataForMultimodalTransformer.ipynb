# %%
import os
import sys
import shutil
import pandas as pd
sys.path.append('..')
from src.data import download_images

# %% [markdown]
# ## Get Data and sort it

# %%
data = pd.read_csv('../data/moderated_data_7_30_24.csv')
# data = pd.read_csv('data/justin_dataset_may_models.csv').rename(columns={'new_url': 'download_url'})

# %%
data.groupby('label')['label'].count()
# Out:
# label
# PG       6704
# PG13    27247
# R       15116
# X        5262
# XXX      2886
# Name: label, dtype: int64

# %%
# # Count the number of rows per label
# label_counts = data.groupby('label')['label'].count()

# # Get the minimum count among all labels
# min_count = label_counts.min()

# Sample equal number of rows per label
balanced_data = data.groupby('label').apply(lambda x: x.sample(n=20000, random_state=42, replace = True)).reset_index(drop=True)

balanced_data.groupby('label')['label'].count()
# Out:
# C:\Users\wolfg\AppData\Local\Temp\ipykernel_19820\2288415652.py:8: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   balanced_data = data.groupby('label').apply(lambda x: x.sample(n=20000, random_state=42, replace = True)).reset_index(drop=True)
# label
# PG      20000
# PG13    20000
# R       20000
# X       20000
# XXX     20000
# Name: label, dtype: int64

# %%
balanced_data.drop_duplicates(subset='download_url', inplace=True)
balanced_data.groupby('label')['label'].count()
# Out:
# label
# PG       6358
# PG13    14143
# R       11069
# X        5145
# XXX      2883
# Name: label, dtype: int64

# %%
balanced_data.head()
# Out:
#                                         download_url  \
# 0  https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7...
# 1  https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7...
# 2  https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7...
# 3  https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7...
# 4  https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7...
#
#                                     url        id  \
# 0  045531bb-1053-400f-9948-dd8989ff89fe   2720387
# 1  9b9ad996-854e-4cbd-ba39-9c04263bb240  15621500
# 2  0b0d979a-1953-4949-94f8-ee31d8393064  15130346
# 3  31cc8e8e-d612-405f-8b36-52d5f3c894f4  15109061
# 4  c360a74b-db63-4a47-9427-f42a47b2706f  11659440
#
#                                                 tags  \
# 0  leather jacket, leather, tight, nose, shiny cl...
# 1  multiple girls, woman, yuri, mole, black hair,...
# 2  long hair, twintails, skirt, sitting, jacket, ...
# 3  female swimwear or underwear, happy, sleeveles...
# 4  solo, long hair, smile, brown hair, realistic,...
#
#                                               prompt  mod_userid  mod_rating  \
# 0  Savage, Classic, Southern Belle, Superhero, Ro...     2345535           1
# 1  score_9, score_8_up, score_7_up, 2girls, prett...      296765           1
# 2  score_9, score_8_up,masterpiece,,hatsune_miku,...      296765           1
# 3  score_9_up, score_8_up, score_7_up, Score_6_up...      296765           1
# 4  realistic photo,photorealistic,hyperrealistic,...           3           1
#
#   label   imageId                                            tag_ids
# 0    PG   2720387  [5262, 5148, 115513, 5453, 5798, 5784, 3642, 7...
# 1    PG  15621500  [111095, 5133, 111006, 112529, 3642, 2193, 160...
# 2    PG  15130346  [5228, 5862, 111960, 5109, 7954, 140256, 5772,...
# 3    PG  15109061  [5262, 116940, 5140, 335, 5148, 5983, 111951, ...
# 4    PG  11659440  [3900, 4836, 15701, 5262, 5228, 5772, 15772, 5...

# %%
## for evaluation:
balanced_data = data
data = {}

# Iterate over the DataFrame
for index, row in balanced_data.iterrows():
    data[index] = {
        "url": row['download_url'], 
        "prompt": row['prompt'],
        "prompt_and_tags": f"{row['tags']}",
        "label": row['label']
    }

# %%
output = '../data/moderator_data/'
download_images(data, output)
# Out:
# 18470889.jpg
# 18469420.jpg
# 18465560.jpg
# 18467840.jpg
# 18467854.jpg
# 18495572.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/67bcf979-a99b-4329-8fe7-769285650990/original=True/18495572.jpg: write() argument must be str, not float
# 18467847.jpg
# 18467845.jpg
# 18473058.jpg
# 18472383.jpg
# 18478581.jpg
# 18470197.jpg
# 18494326.jpg
# 18479761.jpg
# 18494325.jpg
# 18483300.jpg
# 18481313.jpg
# 18494807.jpg
# 18482194.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/be968a90-bb8f-42bf-bafc-e0a71c2db6eb/original=True/18494807.jpg: write() argument must be str, not float
# 18483459.jpg
# 18490625.jpg
# 18487620.jpg
# 18482370.jpg
# 18488296.jpg
# 18483544.jpg
# 18487631.jpg
# 18490206.jpg
# 18493296.jpg
# 12744394.jpg
# 12745111.jpg
# 18492876.jpg
# 18495574.jpg
# 18494330.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d041f559-b235-4a30-8041-bd73850e4c26/original=True/18495574.jpg: write() argument must be str, not float
# 18494332.jpg
# 18495575.jpg
# 12745702.jpg
# 18485887.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d2c17527-bd5d-410d-a61a-e67f1d0fe1ae/original=True/18495575.jpg: write() argument must be str, not float
# 18494345.jpg
# 18490203.jpg
# 18494333.jpg
# 18490207.jpg
# 18494334.jpg
# 8397910.jpg
# 2368782.jpg
# 9583914.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/3d5ccb30-1f17-4cdc-a6da-5cf9de5afbad/original=True/9583914.jpg: write() argument must be str, not float
# 8398112.jpg
# 6483562.jpg
# 9819930.jpg
# 18494323.jpg
# 7792878.jpg
# 9821508.jpg
# 8014532.jpg
# 10404319.jpg
# 18494324.jpg
# 1348099.jpg
# 9526939.jpg
# 10524811.jpg
# 9618837.jpg
# 6428796.jpg
# 9819883.jpg
# 9341090.jpg
# 9868509.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/00d40eba-1fee-4b3b-9694-25c4c2c6d9fb/original=True/9868509.jpg: write() argument must be str, not float
# 8014565.jpg
# 6259525.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f15b94d1-0f09-45dc-b2cc-aac3094bb68e/original=True/6259525.jpg: write() argument must be str, not float
# 9856883.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/53ac32a9-a47c-45ee-a995-8f5298871e73/original=True/9856883.jpg: 'charmap' codec can't encode character '\x84' in position 149: character maps to <undefined>
# 10051167.jpg
# 9875622.jpg
# 10066447.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/032f2a6b-714a-415b-bd9d-7ecd1938f6d1/original=True/9875622.jpg: write() argument must be str, not float
# 9582653.jpg
# 10525428.jpg
# 10360217.jpg
# 9819756.jpg
# 8339008.jpg
# 10396271.jpg
# 10360223.jpg
# 9571495.jpg
# 10361406.jpg
# 10373601.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a8184667-5911-4b9c-b1fc-a1ac48634783/original=True/10361406.jpg: write() argument must be str, not float
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/756928d5-6dd9-4075-90c8-fd303a5859f4/original=True/10453109.jpg: cannot identify image file <_io.BytesIO object at 0x0000015E3499AA20>
# 10372426.jpg
# 10525421.jpg
# 9819652.jpg
# 10345286.jpg
# 10301180.jpg
# 9825565.jpg
# 10399646.jpg
# 10539437.jpg
# 7046198.jpg
# 9819638.jpg
# 8339010.jpg
# 9842107.jpg
# 9635515.jpg
# 9691237.jpg
# 9828774.jpg
# 10525888.jpg
jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2303ab80-9dac-4726-8d7f-7f0dbab31107/original=True/9695669.jpg: write() argument must be str, not float
# 10071941.jpg
# 10072582.jpg
# 10072784.jpg
# 10070569.jpg
# 10074008.jpg
# 9896121.jpg
# 9882297.jpg
# 9774777.jpg
# 1225478.jpg
# 10038550.jpg
# 1347894.jpg
# 10041257.jpg
# 10064594.jpg
# 10068973.jpg
# 10070666.jpg
# 10071929.jpg
# 10059148.jpg
# 10072583.jpg
# 9689678.jpg
# 9833002.jpg
# 9689679.jpg
# 9362508.jpg
# 9902551.jpg
# 10074006.jpg
# 9895734.jpg
# 750386.jpg
# 10071876.jpg
# 10070138.jpg
# 10038554.jpg
# 10070732.jpg
# 10074005.jpg
# 9833005.jpg
# 7265695.jpg
# 9380570.jpg
# 9689675.jpg
# 9696789.jpg
# 1575383.jpg
# 10038557.jpg
# 9871984.jpg
# 9601322.jpg
# 9837222.jpg
# 10059691.jpg
# 10070808.jpg
# 10075465.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/19c60661-233f-49b7-be8c-abdcdf6ad1d6/original=True/10070808.jpg: write() argument must be str, not float
# 10074809.jpg
# 10075037.jpg
# 9022311.jpg
# 9689529.jpg
# 6897956.jpg
# 9632039.jpg
# 9634200.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ce4caeb0-50d5-464f-80e4-a573415610b6/original=True/9634200.jpg: write() argument must be str, not float
# 2503954.jpg
# 9696780.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/706c3b8a-7a5c-4e92-a4a0-659868871680/original=True/6897956.jpg: write() argument must be str, not float
# 9619995.jpg
# 10038556.jpg
# 8313525.jpg
# 8864830.jpg
# 10070826.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/682d5ffb-5220-4460-868d-26d86ded38fe/original=True/10070826.jpg: write() argument must be str, not float
# 10060773.jpg
# 10075039.jpg
# 9833016.jpg
# 9696790.jpg
# 5523973.jpg
# 8991633.jpg
# 9620958.jpg
# 1113875.jpg
# 9636951.jpg
# 10500361.jpg
# 8234525.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/072e3438-cccb-4532-9d1f-b019df6f4be2/original=True/8234525.jpg: 'charmap' codec can't encode character '\u03d5' in position 1: character maps to <undefined>
# 9617493.jpg
# 10039028.jpg
# 10039030.jpg
# 6616424.jpg
# 9839610.jpg
# 9528753.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5cf09aa5-7144-4d53-b4c5-583a3eee3d05/original=True/9528753.jpg: write() argument must be str, not float
# 9838533.jpg
# 10075034.jpg
# 8571299.jpg
# 6116653.jpg
# 9376220.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/94e9393b-0bb4-491f-a85a-b41a9fc62069/original=True/9376220.jpg: write() argument must be str, not float
# 8862649.jpg
# 10070887.jpg
# 8977168.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f1de53a2-362b-47d5-872f-cb0f9a81a688/original=True/10070887.jpg: write() argument must be str, not float
# 8576192.jpg
# 1347885.jpg
# 9691846.jpg
# 10039027.jpg
# 6044885.jpg
# 10075036.jpg
# 9832994.jpg
# 9378136.jpg
# 10070884.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8000fa5c-0fc9-4ec7-a1d6-66c2fca7e084/original=True/10070884.jpg: write() argument must be str, not float
# 9882295.jpg
# 9376011.jpg
# 10039024.jpg
# 9833896.jpg
# 10071038.jpg
# 10039026.jpg
# 9691845.jpg
# 9376151.jpg
# 9636813.jpg
# 2172784.jpg
# 9636243.jpg
# 9691843.jpg
# 10071040.jpg
# 9833894.jpg
# 9375952.jpg
# 9834875.jpg
# 9899752.jpg
# 6451190.jpg
# 8398817.jpg
# 9898631.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/53fba4cc-3a37-4e0d-86a6-7c766cdbdba1/original=True/9898631.jpg: write() argument must be str, not float
# 10071151.jpg
# 10039022.jpg
# 9362488.jpg
# 9394983.jpg
# 9636662.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA
jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/51c9475f-e8e1-4ab9-b7e9-2217cff2aef5/original=True/8586867.jpg: write() argument must be str, not float
# 10353438.jpg
# 10290619.jpg
# 9335321.jpg
# 9885052.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/361d15f4-6b8c-4ad3-932b-9596e0ff7a13/original=True/9335321.jpg: write() argument must be str, not float
# 10353333.jpg
# 9893308.jpg
# 9847749.jpg
# 9380361.jpg
# 9380368.jpg
# 10066348.jpg
# 9644455.jpg
# 10231731.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/698e64c6-ff09-43e0-a92a-313b1fc76901/original=True/10231731.jpg: 'charmap' codec can't encode characters in position 740-741: character maps to <undefined>
# 9644565.jpg
# 8634969.jpg
# 8507327.jpg
# 9353867.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ed8fc99f-eb10-4a18-a040-938efe875975/original=True/9353867.jpg: write() argument must be str, not float
# 9388116.jpg
# 10109439.jpg
# 10353331.jpg
# 9845645.jpg
# 10095910.jpg
# 10231950.jpg
# 9022313.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/5f8a2ff7-80e4-4dc5-8acf-f795ae3e1b40/original=True/10231950.jpg: 'charmap' codec can't encode characters in position 740-741: character maps to <undefined>
# 9849554.jpg
# 8933364.jpg
# 6259553.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/da34c4db-3b1f-4a31-8812-5889f60a063a/original=True/6259553.jpg: write() argument must be str, not float
# 10069672.jpg
# 10073008.jpg
# 10353375.jpg
# 10094275.jpg
# 9874964.jpg
# 6259573.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/e24b38d0-9c6c-447f-9acb-927501cdcd95/original=True/6259573.jpg: write() argument must be str, not float
# 10100793.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b3b93692-9087-4a94-955d-0aa14d49e9af/original=True/10100793.jpg: write() argument must be str, not float
# 8543286.jpg
# 9388118.jpg
# 9380329.jpg
# 10096172.jpg
# 10089216.jpg
# 9800821.jpg
# 10073014.jpg
# 6631248.jpg
# 9687842.jpg
# 10095532.jpg
# 9888859.jpg
# 9715115.jpg
# 5942242.jpg
# 10235321.jpg
# 2062108.jpg
# 10244740.jpg
# 10374902.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/72c4a717-e5b5-4948-b9c9-a779acdc05ce/original=True/10374902.jpg: write() argument must be str, not float
# 10572343.jpg
# 10196361.jpg
# 9907716.jpg
# 10231998.jpg
# 7154843.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0021615b-7c1c-46cf-bf50-34ef89adf88d/original=True/7154843.jpg: write() argument must be str, not float
# 10073013.jpg
# 10353381.jpg
# 10357036.jpg
# 10296364.jpg
# 10581640.jpg
# 10399106.jpg
# 4955856.jpg
# 9866318.jpg
# 10572344.jpg
# 10105863.jpg
# 9764094.jpg
# 10082275.jpg
# 10082277.jpg
# 1967223.jpg
# 10355953.jpg
# 10105755.jpg
# 4845191.jpg
# 8933332.jpg
# 5669824.jpg
# 10073011.jpg
# 9851293.jpg
# 1484218.jpg
# 10232176.jpg
# 9870222.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8256c542-b681-4b65-967d-dcd95d10cd02/original=True/9870222.jpg: write() argument must be str, not float
# 9796819.jpg
# 9881797.jpg
# 8477477.jpg
# 9911269.jpg
# 6113188.jpg
# 10094180.jpg
# 6108037.jpg
# 10233456.jpg
# 1591904.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ae125de8-834a-4c24-884c-fd3243bcf87f/original=True/1591904.jpg: write() argument must be str, not float
# 6116539.jpg
# 10572613.jpg
# 10299691.jpg
# 10358499.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/549e8d88-b216-4557-8449-1411e159089b/original=True/10299691.jpg: write() argument must be str, not float
# 10302046.jpg
# 10518505.jpg
# 10693849.jpg
# 10362461.jpg
# 5669799.jpg
# 5263257.jpg
# 9867015.jpg
# 9886935.jpg
# 10088057.jpg
# 10149501.jpg
# 10209059.jpg
# 10249133.jpg
# 10074399.jpg
# 10237050.jpg
# 6377436.jpg
# 10275136.jpg
# 1337540.jpg
# 5669825.jpg
# 9971214.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a287f901-e468-4a9f-b11e-5355579e3f42/original=True/9971214.jpg: write() argument must be str, not float
# 10360221.jpg
# 10294263.jpg
# 10269087.jpg
# 10344000.jpg
# 10387644.jpg
# 10653574.jpg
# 5459329.jpg
# 9380576.jpg
# 10417259.jpg
# 10394715.jpg
# 10094264.jpg
# 9856904.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9326edfb-38a2-4789-ae8c-8e01cfcee066/original=True/9856904.jpg: 'charmap' codec can't encode character '\x84' in position 149: character maps to <undefined>
# 10074703.jpg
# 10094139.jpg
# 9820815.jpg
# 10237051.jpg
# 10064576.jpg
# 10211083.jpg
# 1511018.jpg
# 10327139.jpg
# 10272740.jpg
# 10359966.jpg
# 10581183.jpg
# 10574487.jpg
# 6565478.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bfeff92f-5a67-43d3-9947-ecc7dd571f0f/original=True/6565478.jpg: write() argument must be str, not float
# 8234747.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/94c7a327-0022-4010-8c59-ab400af19a91/original=True/8234747.jpg: 'charmap' codec can't encode character '\u03d5' in position 1: character maps to <undefined>
# 10763031.jpg
# 6970012.jpg
# 10730536.jpg
# 8234408.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/69e14b75-2890-4b3d-949e-330aec52e8bc/original=True/8234408.jpg: 'charmap' codec can't encode character '\u03d5' in position 1: character maps to <undefined>
# 9725920.jpg
# 9726250.jpg
# 9726335.jpg
# 9381595.jpg
# 10103571.jpg
# 9312180.jpg
# 9726336.jpg
# 9196999.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/93336979-0a18-4879-92f1-a503b7ddcda1/original=True/9196999.jpg: write() argument must be str, not float
# 9726333.jpg
# 8234409.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/47a92b90-6610-46b5-9f85-bcd57e820b5d/original=True/8234409.jpg: 'charmap' codec can't encode character '\u03d5' in position 1: character maps to <undefined>
# 9726674.jpg
# 6259569.jpg
# 10075187.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/cdd74d5d-0918-4fa8-8f97-df5efa04a509/original=True/6259569.jpg: write() argument must be str, not float
# 9725919.jpg
# 9725922.jpg
# 10064578.jpg
# 10201052.jpg
# 10221422.jpg
# 10236589.jpg
# 10251543.jpg
# 1288510.jpg
# 1087177.jpg
# 8638332.jpg
# 10581171.jpg
# 8638335.jpg
# 10573858.jpg
# 8638334.jpg
# 9728559.jpg
# 9728950.jpg
# 10359985.jpg
# 9735404.jpg
# 8638330.jpg
# 9381808.jpg
# 8638337.jpg
# 10237052.jpg
# 9884945.jpg
# 1281333.jpg
# 6451205.jpg
# 9870033.jpg
# 9871295.jpg
# 9871822.jpg
# 10088050.jpg
# 10075230.jpg
# 10360222.jpg
# 9873370.jpg
# 10089348.jpg
# 10095522.jpg
# 5394535.jpg
# 9432630.jpg
# 10580449.jpg
# 4204284.jpg
# 10237033.jpg
# 9380580.jpg
# 10360218.jpg
# 9856334.jpg
# 9580139.jpg
# 10360219.jpg
# 10395347.jpg
# 9884146.jpg
# 10082273.jpg
# 10077184.jpg
# 10143744.jpg
# 10300135.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA
jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/876f6cd4-7548-491d-a827-419fd83cfe21/original=True/10263585.jpg: write() argument must be str, not float
# 8697104.jpg
# 2386637.jpg
# 2412071.jpg
# 8693216.jpg
# 8720521.jpg
# 8720549.jpg
# 8719746.jpg
# 7778122.jpg
# 10099953.jpg
# 8719568.jpg
# 8719522.jpg
# 8719414.jpg
# 8719526.jpg
# 8719365.jpg
# 8719491.jpg
# 8719554.jpg
# 8717490.jpg
# 8718073.jpg
# 8718391.jpg
# 8719416.jpg
# 8715544.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/3258adff-083a-492b-ab4a-c065c2227090/original=True/8715544.jpg: write() argument must be str, not float
# 8717593.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/7a15216e-e140-4305-8064-06d502232663/original=True/8717593.jpg: write() argument must be str, not float
# 8716709.jpg
# 8715475.jpg
# 8715917.jpg
# 8715388.jpg
# 8715250.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/63413d53-6129-49f3-aa32-4905cd3be099/original=True/8715250.jpg: write() argument must be str, not float
# 8717823.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/182b2cf2-d423-4ecb-a4a5-fa88685c4ec1/original=True/8715302.jpg: cannot identify image file <_io.BytesIO object at 0x0000015E391F0220>
# 9388114.jpg
# 8712697.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4a558c69-882c-4214-936e-00d2a88ac5e5/original=True/8712697.jpg: write() argument must be str, not float
# 9866306.jpg
# 8716674.jpg
# 9819300.jpg
# 9869214.jpg
# 9911473.jpg
# 10281130.jpg
# 8708813.jpg
# 9590656.jpg
# 5819527.jpg
# 9042912.jpg
# 10197522.jpg
# 10079082.jpg
# 10424502.jpg
# 9602581.jpg
# 3010802.jpg
# 10576534.jpg
# 10312141.jpg
# 10264067.jpg
# 10259000.jpg
# 9388115.jpg
# 10676810.jpg
# 10243097.jpg
# 10098628.jpg
# 10302694.jpg
# 9936456.jpg
# 8714968.jpg
# 9389706.jpg
# 8714770.jpg
# 9296026.jpg
# 8706109.jpg
# 9819297.jpg
# 9831834.jpg
# 10079444.jpg
# 9893560.jpg
# 9590838.jpg
# 3092017.jpg
# 10242774.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/e17e9602-e075-4dd5-8692-85aa011174e6/original=True/10242774.jpg: write() argument must be str, not float
# 10254468.jpg
# 10263316.jpg
# 10374348.jpg
# 10208989.jpg
# 10317413.jpg
# 10244926.jpg
# 2189444.jpg
# 10373232.jpg
# 10576542.jpg
# 8715217.jpg
# 10220296.jpg
# 8715199.jpg
# 8714372.jpg
# 8713586.jpg
# 8714192.jpg
# 8714649.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/53870fcd-3e4c-4813-9711-5a0a7b698f66/original=True/8714649.jpg: write() argument must be str, not float
# 9388117.jpg
# 8704032.jpg
# 8710121.jpg
# 9871992.jpg
# 8712545.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/596920d7-36ca-43b0-b615-8c34f99baca3/original=True/8712545.jpg: write() argument must be str, not float
# 8711765.jpg
# 9871949.jpg
# 9869212.jpg
# 9819298.jpg
# 10131590.jpg
# 8712696.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/29f63fbe-cbbc-49db-a4a4-9f1f2ee3b9c8/original=True/8712696.jpg: write() argument must be str, not float
# 10079446.jpg
# 9883923.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9e9e0fdb-bbac-48e3-81fb-e23f70a5ef64/original=True/8713910.jpg: cannot identify image file <_io.BytesIO object at 0x0000015E28AFDC60>
# 10138590.jpg
# 9884144.jpg
# 9883925.jpg
# 9878918.jpg
# 3010786.jpg
# 10263780.jpg
# 10261952.jpg
# 10209055.jpg
# 2196000.jpg
# 10220384.jpg
# 10251587.jpg
# 1569374.jpg
# 10576530.jpg
# 10265062.jpg
# 10207203.jpg
# 10685032.jpg
# 5424148.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f014f8b3-125d-47dd-93d4-ef35d5a78db4/original=True/5424148.jpg: 'charmap' codec can't encode character '\x94' in position 207: character maps to <undefined>
# 8711547.jpg
# 10736453.jpg
# 9292480.jpg
# 8711212.jpg
# 8712398.jpg
# 8711006.jpg
# 8703927.jpg
# ...
# 20555358.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8ff33c17-456a-40e9-a6e8-1fd196b52c4d/original=True/20555358.jpg: write() argument must be str, not float
# 3352637.jpg
# 3763945.jpg
# 20533713.jpg
# 20573463.jpg
# 20535706.jpg
# 20519765.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/b3998dd5-7600-4071-81b7-5d4b6be4e0f8/original=True/20535706.jpg: write() argument must be str, not float
# 3250441.jpg
# 2404849.jpg
# 20588763.jpg
# 20580920.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9b76d436-fe57-4910-a345-77ad10b303b9/original=True/20580920.jpg: write() argument must be str, not float
# 20580930.jpg
# 20580942.jpg
# 20579464.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4de13a8e-b3b5-487b-8b72-3ecedbf93b15/original=True/20580930.jpg: write() argument must be str, not float
# 20595372.jpg
# 20580934.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a7cc7266-4d66-4c2f-a9d6-fd52e82bb5ac/original=True/20580934.jpg: write() argument must be str, not float
# 19565026.jpg
# 20610551.jpg
# 20508459.jpg
# 20612498.jpg
# 20536942.jpg
# 20541212.jpg
# 20536943.jpg
# 20549267.jpg
# 20549264.jpg
# 20549263.jpg
# 20549415.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/4ee181cc-2197-4dc1-be46-802c27faee35/original=True/20549415.jpg: write() argument must be str, not float
# 20525784.jpg
# 20533329.jpg
# 20550926.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8ab12bfb-6e00-4aeb-9c0f-6c911313b68c/original=True/20533329.jpg: write() argument must be str, not float
# 20557516.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/3a4f8f97-7866-44a4-8fc7-187baac654c3/original=True/20557516.jpg: write() argument must be str, not float
# 20551679.jpg
# 20478666.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/977c2219-322d-41d0-99a6-5bd4309c9b40/original=True/20551679.jpg: write() argument must be str, not float
# 20557768.jpg
# 20563890.jpg
# 20550341.jpg
# 20563761.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2f8b3472-9b0a-467f-9f3d-bca0924030ef/original=True/20563761.jpg: write() argument must be str, not float
# 19565029.jpg
# 2122312.jpg
# 20549271.jpg
# 20452894.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8571a0bc-734c-4b62-9002-f8adfd54175f/original=True/20452894.jpg: write() argument must be str, not float
# 3475772.jpg
# 20559596.jpg
# 2351148.jpg
# 20580925.jpg
# 20549130.jpg
# 20577129.jpg
# 20555639.jpg
# 20552501.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/11844395-05cd-411b-a77d-aabc52a51e12/original=True/20552501.jpg: write() argument must be str, not float
# 20555640.jpg
# 20610532.jpg
# 20612497.jpg
# 20557012.jpg
# 20569493.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2b437711-b196-4a5b-827b-fd4a60e9648a/original=True/20557012.jpg: write() argument must be str, not float
# 20580941.jpg
# 2412189.jpg
# 20243656.jpg
# 20234602.jpg
# 20557767.jpg
# 20557011.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8688c632-24d3-4d69-9b11-19f1c83bbcf9/original=True/20557011.jpg: write() argument must be str, not float
# 20557013.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/05bad888-4a61-4e93-bebf-180239f7265b/original=True/20557013.jpg: write() argument must be str, not float
# 20553466.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f8518ec7-9664-4497-9703-ae9a64f6d5af/original=True/20553466.jpg: write() argument must be str, not float
# 20559548.jpg
# 3532693.jpg
# 20550337.jpg
# 20559577.jpg
# 2318433.jpg
# 2846275.jpg
# 20559583.jpg
# 4332584.jpg
# 20559631.jpg
# 20610564.jpg
# 20588766.jpg
# 20593286.jpg
# 4295207.jpg
# 20239200.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9b6bcab0-dee2-4419-a092-0d87b3570079/original=True/20239200.jpg: write() argument must be str, not float
# 20550318.jpg
# 20559584.jpg
# 20610677.jpg
# 20550317.jpg
# 20605854.jpg
# 2570449.jpg
# 2351149.jpg
# 2351146.jpg
# 20435838.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d8517118-201b-465c-bbc7-564dd96004a7/original=True/20435838.jpg: write() argument must be str, not float
# 3600982.jpg
# 20561559.jpg
# 20559586.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/c61177b0-837f-4d94-a6be-cd8ba7edabb4/original=True/20561559.jpg: write() argument must be str, not float
# 20569465.jpg
# 20549137.jpg
# 3600948.jpg
# 2193174.jpg
# 20532972.jpg
# 3352214.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0a0f95f4-5e43-408c-90d1-42575b1a50fc/original=True/20532972.jpg: write() argument must be str, not float
# 20430114.jpg
# 2122313.jpg
# 2412172.jpg
# 2363857.jpg
# 20580940.jpg
# 20459835.jpg
# 20603551.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/d35b5998-da91-44e5-8855-349da089d0f8/original=True/20603551.jpg: write() argument must be str, not float
# 2429677.jpg
# 19565027.jpg
# 3475777.jpg
# 3532695.jpg
# 2412209.jpg
# 2429618.jpg
# 3533783.jpg
# 2086316.jpg
# 20565204.jpg
# 2432224.jpg
# 3376323.jpg
# 2846277.jpg
# 3378258.jpg
# 20578928.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/f576ad64-7752-49ad-924c-30feee6be918/original=True/20578928.jpg: write() argument must be str, not float
# 20591330.jpg
# 20359168.jpg
# 20593972.jpg
# 3577742.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/958bbe0e-020c-468e-9e9a-7e3732bb0d18/original=True/20359168.jpg: write() argument must be str, not float
# 3403839.jpg
# 20609294.jpg
# 20579315.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/630c27cf-88de-4a05-9aad-a5d8e4471011/original=True/20579315.jpg: write() argument must be str, not float
# 2937063.jpg
# 3600947.jpg
# 2290194.jpg
# 20564734.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/25da7dd4-8c0f-40f0-b0d5-c4bfffd2ea41/original=True/20564734.jpg: write() argument must be str, not float
# 2274778.jpg
# 20588776.jpg
# 2351196.jpg
# 20585424.jpg
# 20593285.jpg
# 20591435.jpg
# 20460272.jpg
# 20603543.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/178e1d58-f26c-48cb-9e2f-e920393dd7bf/original=True/20603543.jpg: write() argument must be str, not float
# 20610540.jpg
# 20603514.jpg
# 2122216.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a5134111-8b01-410b-a5dd-de8c6ba430f5/original=True/20603514.jpg: write() argument must be str, not float
# 2404850.jpg
# 3601759.jpg
# 20578136.jpg
# 20585426.jpg
# 20549146.jpg
# 3864017.jpg
# 20588063.jpg
# 20610534.jpg
# 20605969.jpg
# 20610698.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/632b10b5-0a81-4afd-a31b-98a9b483c879/original=True/20605969.jpg: write() argument must be str, not float
# 20607203.jpg
# 3403921.jpg
# 2335776.jpg
# 20605858.jpg
# 3768556.jpg
# 19565036.jpg
# 2211405.jpg
# 2937062.jpg
# 19541824.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/2cd8a525-3811-4a34-a5b0-585b4811ed3e/original=True/19541824.jpg: write() argument must be str, not float
# 20566092.jpg
# 3352216.jpg
# 20565211.jpg
# 3298662.jpg
# 20568718.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0114ba77-0422-4fdb-a722-c9b471df8ba0/original=True/20568718.jpg: write() argument must be str, not float
# 20512641.jpg
# 2466502.jpg
# 3378225.jpg
# 3352218.jpg
# 20569435.jpg
# 20569521.jpg
# 20568814.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/36d0cae9-3379-4f01-96dd-3bc80b96ffdf/original=True/20569435.jpg: write() argument must be str, not float
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/8b77119a-16ce-4374-9fa0-746d2078140c/original=True/20568814.jpg: write() argument must be str, not float
# 20572863.jpg
# 19776914.jpg
# 20550454.jpg
# 20571740.jpg
# 20438289.jpg
# 20580944.jpg
# 20577667.jpg
# 4418896.jpg
# 20577132.jpg
# 20569523.jpg
# 20580937.jpg
# 4332583.jpg
# 20580943.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/03144d63-e49b-4f01-b65b-6fe9e08e7b8d/original=True/20580943.jpg: write() argument must be str, not float
# 20580933.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/1f9b2298-045b-44a7-b31b-89fefc7c975c/original=True/20580933.jpg: write() argument must be str, not float
# 20580938.jpg
# 20580932.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9f7b5aab-e286-44ac-9d01-a72abf52cbfa/original=True/20580932.jpg: write() argument must be str, not float
# 20580935.jpg
# 20549140.jpg
# 20580939.jpg
# 20580931.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a5ca2247-64e9-46e4-8a2b-1eaa23df6fd1/original=True/20580931.jpg: write() argument must be str, not float
# 20549136.jpg
# 20585819.jpg
# 20585425.jpg
# 20549167.jpg
# 20585423.jpg
# 20588765.jpg
# 20580929.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/6d6eb40d-460d-4ff2-b321-a52179a08e32/original=True/20580929.jpg: write() argument must be str, not float
# 20591511.jpg
# 20585875.jpg
# 20592223.jpg
# 20598093.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/1fdefd14-8e4d-4a41-865e-b0c9225c1a5e/original=True/20598093.jpg: write() argument must be str, not float
# 20594720.jpg
# 20591434.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/9aa19c1b-482f-45d9-91c7-1857fbbdd374/original=True/20592223.jpg: write() argument must be str, not float
# 20515466.jpg
# 862772.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/75c7e25c-cb3c-419d-836b-d0336ab6df42/original=True/20515466.jpg: write() argument must be str, not float
# 20603554.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bc0b7c9d-4e81-4096-8dcf-778185abb125/original=True/20603554.jpg: write() argument must be str, not float
# 20603555.jpg
# 20603501.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ba570b09-7fff-47ac-9fea-7fa4e22639e6/original=True/20603555.jpg: write() argument must be str, not float
# 20515461.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/dabba8cd-c791-4992-a190-c3e34c36929c/original=True/20603501.jpg: write() argument must be str, not float
# 20598259.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/0e9a7833-3b75-40b7-95de-018f27294648/original=True/20515461.jpg: write() argument must be str, not float
# 20603519.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/991bf4d1-80cd-40f9-a4b7-c12d5295567e/original=True/20603519.jpg: write() argument must be str, not float
# 20107101.jpg
# 20603502.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/01378353-4422-419a-9b51-97a41f8b5c73/original=True/20603502.jpg: write() argument must be str, not float
# 20603499.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/65dad4bc-798b-4a35-bad4-352fb7778401/original=True/20603499.jpg: write() argument must be str, not float
# 19565035.jpg
# 19798738.jpg
# 20605625.jpg
# 20605724.jpg
# 19655683.jpg
# 20599750.jpg
# 20610552.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/c8b2b84f-ed89-48cb-8822-a84dcbe2163f/original=True/20599750.jpg: write() argument must be str, not float
# 20610525.jpg
# 20605857.jpg
# 20610775.jpg
# 20612110.jpg
# 20610562.jpg
# 20612654.jpg
# 20605004.jpg
# 20605856.jpg
# 20474850.jpg
# 20612500.jpg
# 20235984.jpg
# 20549125.jpg
# 20549143.jpg
# 20549121.jpg
# 20592235.jpg
# 20586755.jpg
# 20414859.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/73f62267-6441-4653-a512-30838e290245/original=True/20414859.jpg: write() argument must be str, not float
# 20588764.jpg
# 20603547.jpg
# 20598089.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/33918798-4c9a-4432-a827-49958c059c29/original=True/20598089.jpg: write() argument must be str, not float
# 20603525.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/038ed125-a498-4b36-a8a3-249a44f299f9/original=True/20603547.jpg: write() argument must be str, not float
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/ea4d6495-0b23-4e86-9463-dcf39a19508f/original=True/20603525.jpg: write() argument must be str, not float
# 20605213.jpg
# 20559619.jpg
# 19565028.jpg
# 20609292.jpg
# 20610536.jpg
# 20591437.jpg
# 20610694.jpg
# 20610693.jpg
# 20599314.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/967c9b9b-aa6e-4823-8f90-b9cfcc242e13/original=True/20599314.jpg: write() argument must be str, not float
# 20612651.jpg
# 20612650.jpg
# 20515459.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/56d8a267-e5c8-43bc-9f2f-16ed42df1832/original=True/20515459.jpg: write() argument must be str, not float
# 20613184.jpg
# 20578605.jpg
# 20613260.jpg
# 20612653.jpg
# 20612125.jpg
# 20236227.jpg
# 20474849.jpg
# 20243828.jpg
# 20243833.jpg
# 20234725.jpg
# 20614824.jpg
# 15102537.jpg
# 20231908.jpg
# 20233567.jpg
# 20616145.jpg
# 20614122.jpg
# 20616973.jpg
# 20617808.jpg
# 20617948.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/633bd4d6-d021-48a7-b396-5ed5761baffa/original=True/20617808.jpg: cannot write mode P as JPEG
# 20617946.jpg
# 20616976.jpg
# 20618254.jpg
# 20614819.jpg
# 20617950.jpg
# 20618219.jpg
# 20618184.jpg
# 20618497.jpg
# 20618336.jpg
# 20618216.jpg
# 20625225.jpg
# 20620042.jpg
# 20619100.jpg
# 20620069.jpg
# 20620071.jpg
# 20620080.jpg
# 20625227.jpg
# 20577555.jpg
# 20637311.jpg
# 20651384.jpg
# 20620097.jpg
# 20637315.jpg
# 20637312.jpg
# 20623930.jpg
# 20642537.jpg
# 20619059.jpg
# 21178257.jpg
# 20642536.jpg
# 20623931.jpg
# 20644605.jpg
# 20678699.jpg
# 13450870.jpg
# 20624525.jpg
# 20681162.jpg
# 20681164.jpg
# 20681804.jpg
# 20681165.jpg
# 21178215.jpg
# 20682670.jpg
# 20684766.jpg
# 20685375.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/bc89ea6c-9ac0-4350-82cd-5ded7d15d227/original=True/20685375.jpg: write() argument must be str, not float
# 21178213.jpg
# 20694064.jpg
# 20693763.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/a9c00449-6f3d-4b3a-9b64-d4f4fba6ae84/original=True/20693763.jpg: 'charmap' codec can't encode character '\x82' in position 270: character maps to <undefined>
# 20694065.jpg
# 20694410.jpg
# 20693969.jpg
# 20694414.jpg
# 20694062.jpg
# 20694420.jpg
# 20694432.jpg
# 20694419.jpg
# 20694422.jpg
# 21178214.jpg
# 20687462.jpg
# 20692190.jpg
# 20687447.jpg
# 20690375.jpg
# 20690381.jpg
# 20693279.jpg
# 20690383.jpg
# 20702013.jpg
# 20703124.jpg
# 20704118.jpg
# 20707301.jpg
# 20706656.jpg
# 20690374.jpg
# 20707304.jpg
# 20709510.jpg
# 20702228.jpg
# 20704734.jpg
# 20712585.jpg
# 20712583.jpg
# 20712581.jpg
# 20712586.jpg
# 20711600.jpg
# Error processing image from https://image.civitai.com/xG1nkqKTMzGDvpLrqFT7WA/dd7639c7-e48d-4262-bf07-4a096c9e24a8/original=True/20711600.jpg: write() argument must be str, not float
# 20712591.jpg
# 20712582.jpg
# 20712588.jpg
# 20712593.jpg
# 20712596.jpg
# 20712598.jpg
# 20712599.jpg
# 20712782.jpg
# 20712780.jpg
# 20713437.jpg
# 20714438.jpg
# 20715144.jpg
# 20715143.jpg
# 20715591.jpg
# 20716198.jpg
# 20716200.jpg
# 20712600.jpg
# 20716203.jpg
# 20716415.jpg
# 20716210.jpg
# 20716420.jpg
# 20716209.jpg
# 20716643.jpg
# 20716208.jpg
# 20716421.jpg
# 20717228.jpg
# 20719766.jpg
# 20717225.jpg
# 20717889.jpg
# 20719762.jpg
# 20717413.jpg
# 20720055.jpg
# 20720906.jpg
# 20729357.jpg
# 20720922.jpg
# 20728580.jpg
# 20729355.jpg
# 20730071.jpg
# 20717127.jpg
# 20732093.jpg
# 20731418.jpg
# 20732485.jpg
# 20732103.jpg
# 20733005.jpg
# 21421080.jpg
# 21423979.jpg
# 21424564.jpg
# 21424560.jpg
# 20730776.jpg
# 21424556.jpg
# 20877534.jpg
# 21424721.jpg
# 21424536.jpg
# 21425308.jpg
# 21422107.jpg
# 21425657.jpg
# 21424439.jpg
# 21424724.jpg
# 21427205.jpg
# 21190973.jpg
# 20797427.jpg
# 21425209.jpg

# %%
for i in os.listdir(output):
    path = os.path.join(output, i)
    print(i, len([i for i in os.listdir(path) if i.endswith('.txt') and 'tags' not in i]))
    print(i, len([i for i in os.listdir(path) if i.endswith('.jpg')]))
# Out:
# PG 6593
# PG 6593
# PG13 27022
# PG13 27022
# R 15044
# R 15044
# X 5215
# X 5215
# XXX 2870
# XXX 2870

# %% [markdown]
# ## Use loop for training data

# %%
# # Define the source directory containing class-specific folders
# source_dir = './data/training_data/'

# # Define the output directories for training and validation
# output_train_dir = './data/datasets/may/train'
# output_val_dir = './data/datasets/may/val'

# # Create the output directories if they don't exist
# os.makedirs(output_train_dir, exist_ok=True)
# os.makedirs(output_val_dir, exist_ok=True)

# # Iterate over each class-specific folder
# for class_name in os.listdir(source_dir):
#     class_path = os.path.join(source_dir, class_name)
    
#     if os.path.isdir(class_path):
#         # List of all .txt files (excluding those with 'tags' in their name)
#         txt_files = [f for f in os.listdir(class_path) if f.endswith('.txt') and 'tags' not in f]
        
#         num_files = len(txt_files)
#         train_split = int(num_files * 0.85)
        
#         # Create lists of indices for training and validation sets
#         shuffled_indices = list(range(num_files))
#         random.shuffle(shuffled_indices)
#         train_indices = shuffled_indices[:train_split]
#         val_indices = shuffled_indices[train_split:]

#         print(f"Class '{class_name}':")
#         print(f"  Train indices: {len(train_indices)}")
#         print(f"  Val indices: {len(val_indices)}")

#         # Copy files into 'train' and 'val' directories
#         for i in train_indices:
#             txt_file = txt_files[i]
#             img_file = txt_file.replace('.txt', '.jpg')  # Assume corresponding .jpg files
            
#             # Source paths
#             src_txt_path = os.path.join(class_path, txt_file)
#             src_img_path = os.path.join(class_path, img_file)
            
#             # Destination paths
#             dest_txt_path = os.path.join(output_train_dir, class_name, txt_file)
#             dest_img_path = os.path.join(output_train_dir, class_name, img_file)
            
#             # Copy the files
#             os.makedirs(os.path.join(output_train_dir, class_name), exist_ok=True)
#             shutil.copy2(src_txt_path, dest_txt_path)
#             if os.path.exists(src_img_path):
#                 shutil.copy2(src_img_path, dest_img_path)

#         for i in val_indices:
#             txt_file = txt_files[i]
#             img_file = txt_file.replace('.txt', '.jpg')  # Assume corresponding .jpg files
            
#             # Source paths
#             src_txt_path = os.path.join(class_path, txt_file)
#             src_img_path = os.path.join(class_path, img_file)
            
#             # Destination paths
#             dest_txt_path = os.path.join(output_val_dir, class_name, txt_file)
#             dest_img_path = os.path.join(output_val_dir, class_name, img_file)
            
#             os.makedirs(os.path.join(output_val_dir, class_name), exist_ok=True)
            
#             # Copy the files
#             shutil.copy2(src_txt_path, dest_txt_path)
#             if os.path.exists(src_img_path):
#                 shutil.copy2(src_img_path, dest_img_path)

# print("File copying complete!")

# %% [markdown]
# ## User loop for eval

# %%
# Define the output directories for training and validation
output_eval_dir = os.path.join(output_dir, 'eval')

# Create the output directories if they don't exist
os.makedirs(output_eval_dir, exist_ok=True)

# Iterate over each class-specific folder
for class_name in os.listdir(output_dir):
    class_path = os.path.join(output_dir, class_name)
    
    if os.path.isdir(class_path):
        # List of all .txt files (excluding those with 'tags' in their name)
        txt_files = [f for f in os.listdir(class_path) if f.endswith('.txt') and 'tags' not in f]
        
        num_files = len(txt_files)
        train_split = int(num_files * 0.85)
        
        # Create lists of indices for training and validation sets
        train_indices = list(range(num_files))

        print(f"Class '{class_name}':")
        print(f"Eval Files: {len(train_indices)}")

        # Copy files into 'train' and 'val' directories
        for i in train_indices:
            txt_file = txt_files[i]
            img_file = txt_file.replace('.txt', '.jpg')  # Assume corresponding .jpg files
            
            # Source paths
            src_txt_path = os.path.join(class_path, txt_file)
            src_img_path = os.path.join(class_path, img_file)
            
            # Destination paths
            dest_txt_path = os.path.join(output_eval_dir, class_name, txt_file)
            dest_img_path = os.path.join(output_eval_dir, class_name, img_file)
            
            # Copy the files
            os.makedirs(os.path.join(output_eval_dir, class_name), exist_ok=True)
            shutil.copy2(src_txt_path, dest_txt_path)
            if os.path.exists(src_img_path):
                shutil.copy2(src_img_path, dest_img_path)

print("File copying complete!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Define the output directories for training and validation
# ----> 2 output_eval_dir = os.path.join(output_dir, 'eval')
#       4 # Create the output directories if they don't exist
#       5 os.makedirs(output_eval_dir, exist_ok=True)
#
# NameError: name 'output_dir' is not defined
